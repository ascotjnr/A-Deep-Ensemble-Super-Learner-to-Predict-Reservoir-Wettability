# %%
#!pip install scikit-learn==0.24.2
# Out:
# Requirement already satisfied: scikit-learn==0.24.2 in c:\users\user\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn==0.24.2) (1.19.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn==0.24.2) (1.5.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn==0.24.2) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn==0.24.2) (2.1.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
import sklearn
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_tweedie_deviance
from sklearn.metrics import r2_score

# Hide Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df_train = pd.read_csv(r"C:\Users\User\Desktop\codes_data\Train Data Carb.csv")
df_train.head()
# Out:
#          MD     GR  PEFZ      SP  S-sonic     SEXP      SESP        RT  \
# 0  1756.562  27.64  7.37 -412.38   123.43  10.7475   78.3657  108.2183
# 1  1747.418  32.46  6.77 -424.69   149.03   7.2472  111.9623  128.2477
# 2  1950.720  31.04  7.57 -334.81   161.29   0.8564    5.8217    5.3824
# 3  1940.052  37.18  6.12 -337.25   134.08   5.3996   18.0115   19.4655
# 4  1765.249  30.73  7.25 -413.81   134.00   6.5137   98.0988  167.9960
#
#      RHOB  New_feat  New_feat2  New_feat3    NPHI  PHITCPX      K      SW  \
# 0  2.4458  1.269370   0.333298   7.773877  0.0358   0.0992   9.31  0.5190
# 1  2.2552  0.062469   1.049670  31.360640  0.0981   0.2801  10.70  0.0277
# 2  2.2780  0.256275   6.784122   1.740688  0.1362   0.2990  49.81  0.1125
# 3  2.5448  1.364522   0.022260   3.915700  0.1113   0.2174   0.20  0.5362
# 4  2.4636  1.638540   0.279549  14.557862  0.1047   0.1484   2.67  0.6651
#
#       T2LM_L
# 0  122.91400
# 1  499.09260
# 2   60.21747
# 3   84.08492
# 4  129.75230

# %%
df_test = pd.read_csv(r"C:\Users\User\Desktop\codes_data\Test Data Carb.csv")
df_test.head()
# Out:
#          MD     GR  PEFZ      SP  S-sonic     SEXP       SESP          RT  \
# 0  1909.724  41.96  6.42 -363.13   148.96   3.1383     8.2482      7.5727
# 1  1786.433  36.24  7.01 -403.88   159.32   2.0840   336.5056    657.0143
# 2  1751.076  31.19  7.23 -419.25   144.80   5.1604   160.6909    393.2737
# 3  1696.822  36.82  5.71 -406.25   192.71  23.3661  4986.6070  28475.5300
# 4  1680.820  96.54  5.34 -394.63   274.52   2.0760     1.7166      1.7492
#
#      RHOB  New_feat  New_feat2    New_feat3    NPHI  PHITCPX       K      SW  \
# 0  2.5097  2.104634   1.372072     1.214135  0.1336   0.1472   10.27  0.8386
# 1  2.2738  0.273766  12.881616   116.329986  0.1574   0.3457   81.84  0.1204
# 2  2.2351  0.808883   0.404910    41.136870  0.0990   0.2560    4.09  0.3619
# 3  1.8283  0.000000  63.295900  2761.582957  0.0925   0.5538  684.28  0.0000
# 4  2.4744  2.279417   0.002958     0.318086  0.2958   0.1853    0.01  0.9212
#
#        T2LM_L
# 0   73.434000
# 1  739.379100
# 2  340.794200
# 3  233.766500
# 4    7.627165

# %%
#df_train.drop(columns = df_train.columns[0],
#             axis = 1,
#             inplace = True)
#df_train.head()
# Out:
#       GR  PEFZ      SP  S-sonic  P-sonic     SEXP      SESP        RT    RHOB  \
# 0  27.64  7.37 -412.38   123.43    68.92  10.7475   78.3657  108.2183  2.4458
# 1  32.46  6.77 -424.69   149.03    79.94   7.2472  111.9623  128.2477  2.2552
# 2  31.04  7.57 -334.81   161.29    67.09   0.8564    5.8217    5.3824  2.2780
# 3  37.18  6.12 -337.25   134.08    79.21   5.3996   18.0115   19.4655  2.5448
# 4  30.73  7.25 -413.81   134.00    67.67   6.5137   98.0988  167.9960  2.4636
#
#      DRHO    NPHI  PHITCPX      K      SW     T2LM_L
# 0  0.0339  0.0358   0.0992   9.31  0.5190  122.91400
# 1  0.0057  0.0981   0.2801  10.70  0.0277  499.09260
# 2 -0.0474  0.1362   0.2990  49.81  0.1125   60.21747
# 3  0.0290  0.1113   0.2174   0.20  0.5362   84.08492
# 4  0.0007  0.1047   0.1484   2.67  0.6651  129.75230

# %%
#df_test.drop(columns = df_test.columns[0],
#             axis = 1,
#             inplace = True)
#df_test.head()
# Out:
#       GR  PEFZ      SP  S-sonic  P-sonic     SEXP       SESP          RT  \
# 0  41.96  6.42 -363.13   148.96    84.22   3.1383     8.2482      7.5727
# 1  36.24  7.01 -403.88   159.32    96.60   2.0840   336.5056    657.0143
# 2  31.19  7.23 -419.25   144.80    68.64   5.1604   160.6909    393.2737
# 3  36.82  5.71 -406.25   192.71   103.80  23.3661  4986.6070  28475.5300
# 4  96.54  5.34 -394.63   274.52   144.94   2.0760     1.7166      1.7492
#
#      RHOB    DRHO    NPHI  PHITCPX       K      SW      T2LM_L
# 0  2.5097  0.0242  0.1336   0.1472   10.27  0.8386   73.434000
# 1  2.2738 -0.0020  0.1574   0.3457   81.84  0.1204  739.379100
# 2  2.2351 -0.0018  0.0990   0.2560    4.09  0.3619  340.794200
# 3  1.8283 -0.0020  0.0925   0.5538  684.28  0.0000  233.766500
# 4  2.4744 -0.0001  0.2958   0.1853    0.01  0.9212    7.627165

# %%
#set MD as index
df_train = df_train.set_index('MD')
df_train.head()
# Out:
#              GR  PEFZ      SP  S-sonic     SEXP      SESP        RT    RHOB  \
# MD
# 1756.562  27.64  7.37 -412.38   123.43  10.7475   78.3657  108.2183  2.4458
# 1747.418  32.46  6.77 -424.69   149.03   7.2472  111.9623  128.2477  2.2552
# 1950.720  31.04  7.57 -334.81   161.29   0.8564    5.8217    5.3824  2.2780
# 1940.052  37.18  6.12 -337.25   134.08   5.3996   18.0115   19.4655  2.5448
# 1765.249  30.73  7.25 -413.81   134.00   6.5137   98.0988  167.9960  2.4636
#
#           New_feat  New_feat2  New_feat3    NPHI  PHITCPX      K      SW  \
# MD
# 1756.562  1.269370   0.333298   7.773877  0.0358   0.0992   9.31  0.5190
# 1747.418  0.062469   1.049670  31.360640  0.0981   0.2801  10.70  0.0277
# 1950.720  0.256275   6.784122   1.740688  0.1362   0.2990  49.81  0.1125
# 1940.052  1.364522   0.022260   3.915700  0.1113   0.2174   0.20  0.5362
# 1765.249  1.638540   0.279549  14.557862  0.1047   0.1484   2.67  0.6651
#
#              T2LM_L
# MD
# 1756.562  122.91400
# 1747.418  499.09260
# 1950.720   60.21747
# 1940.052   84.08492
# 1765.249  129.75230

# %%
#set MD as index
df_test = df_test.set_index('MD')
df_test.head()
# Out:
#              GR  PEFZ      SP  S-sonic     SEXP       SESP          RT  \
# MD
# 1909.724  41.96  6.42 -363.13   148.96   3.1383     8.2482      7.5727
# 1786.433  36.24  7.01 -403.88   159.32   2.0840   336.5056    657.0143
# 1751.076  31.19  7.23 -419.25   144.80   5.1604   160.6909    393.2737
# 1696.822  36.82  5.71 -406.25   192.71  23.3661  4986.6070  28475.5300
# 1680.820  96.54  5.34 -394.63   274.52   2.0760     1.7166      1.7492
#
#             RHOB  New_feat  New_feat2    New_feat3    NPHI  PHITCPX       K  \
# MD
# 1909.724  2.5097  2.104634   1.372072     1.214135  0.1336   0.1472   10.27
# 1786.433  2.2738  0.273766  12.881616   116.329986  0.1574   0.3457   81.84
# 1751.076  2.2351  0.808883   0.404910    41.136870  0.0990   0.2560    4.09
# 1696.822  1.8283  0.000000  63.295900  2761.582957  0.0925   0.5538  684.28
# 1680.820  2.4744  2.279417   0.002958     0.318086  0.2958   0.1853    0.01
#
#               SW      T2LM_L
# MD
# 1909.724  0.8386   73.434000
# 1786.433  0.1204  739.379100
# 1751.076  0.3619  340.794200
# 1696.822  0.0000  233.766500
# 1680.820  0.9212    7.627165

# %%
# create the inputs and outputs for train data
X_train = df_train.drop(['T2LM_L', 'New_feat2', 'New_feat3'], 1) #Feature Matrix
y_train = df_train[['T2LM_L']]

# %%
# create the inputs and outputs for test data
X_test = df_test.drop(['T2LM_L', 'New_feat2', 'New_feat3'], 1) #Feature Matrix
y_test = df_test[['T2LM_L']]

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import AdaBoostRegressor

# %%
# XGBoost Regressor
model = AdaBoostRegressor()

model.fit(X_train, y_train)

# evaluate the model
pred = model.predict(X_test)

# Evaluate model predictions

model_score_train = model.score(X_train, y_train)
model_score_test = model.score(X_test, y_test)
model_mae = metrics.mean_absolute_error(y_test, pred)
model_mse = metrics.mean_squared_error(y_test, pred)
model_rmse = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('Accuracy of train data:',model_score_train)
print('Accuracy of test data:',model_score_test)
print('Mean Absolute Error:',model_mae)  
print('Mean Squared Error:',model_mse)  
print('Root Mean Squared Error:',model_rmse)
print('MAPE %.3f' % (metrics.mean_absolute_percentage_error(y_test, pred)))
print('MPD %.3f' % (metrics.mean_tweedie_deviance(y_test, pred, power=1)))
# Out:
# Accuracy of train data: 0.7614346177164305
# Accuracy of test data: 0.7053378923554435
# Mean Absolute Error: 103.18942090165584
# Mean Squared Error: 16315.300570568508
# Root Mean Squared Error: 127.73136095168057
# MAPE 3.600
# MPD 78.571

# %%
# without new feature 1

# %%
# create the inputs and outputs for train data
X_train = df_train.drop(['T2LM_L', 'New_feat', 'New_feat2', 'New_feat3'], 1) #Feature Matrix
y_train = df_train[['T2LM_L']]

# %%
# create the inputs and outputs for test data
X_test = df_test.drop(['T2LM_L', 'New_feat', 'New_feat2', 'New_feat3'], 1) #Feature Matrix
y_test = df_test[['T2LM_L']]

# %%
# XGBoost Regressor
model = AdaBoostRegressor()

model.fit(X_train, y_train)

# evaluate the model
pred = model.predict(X_test)

# Evaluate model predictions

model_score_train = model.score(X_train, y_train)
model_score_test = model.score(X_test, y_test)
model_mae = metrics.mean_absolute_error(y_test, pred)
model_mse = metrics.mean_squared_error(y_test, pred)
model_rmse = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('Accuracy of train data:',model_score_train)
print('Accuracy of test data:',model_score_test)
print('Mean Absolute Error:',model_mae)  
print('Mean Squared Error:',model_mse)  
print('Root Mean Squared Error:',model_rmse)
print('MAPE %.3f' % (metrics.mean_absolute_percentage_error(y_test, pred)))
print('MPD %.3f' % (metrics.mean_tweedie_deviance(y_test, pred, power=1)))
# Out:
# Accuracy of train data: 0.7555773623964642
# Accuracy of test data: 0.6937635192774441
# Mean Absolute Error: 107.80649579993252
# Mean Squared Error: 16956.168095724643
# Root Mean Squared Error: 130.21585193717638
# MAPE 3.743
# MPD 82.714

# %% [markdown]
# ## Bayesian optimisation does not run with scikit-learn version 0.24.1. Also, version 0.23.1 does not work calculate MAPE and MPD

# %%
# !pip install scikit-optimize
from skopt import gp_minimize
from skopt import BayesSearchCV
from skopt.space import Integer, Real
# Out:
# Requirement already satisfied: scikit-optimize in c:\users\user\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-optimize) (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from scikit-optimize) (1.19.2)
# Requirement already satisfied: pyaml>=16.9 in c:\users\user\anaconda3\lib\site-packages (from scikit-optimize) (21.10.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from scikit-optimize) (0.17.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\user\anaconda3\lib\site-packages (from scikit-optimize) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.1.0)
# Requirement already satisfied: PyYAML in c:\users\user\anaconda3\lib\site-packages (from pyaml>=16.9->scikit-optimize) (5.3.1)

# %%
# create the inputs and outputs for train data
X_train = df_train.drop(['T2LM_L', 'New_feat2', 'New_feat3'], 1) #Feature Matrix
y_train = df_train[['T2LM_L']]

# %%
# create the inputs and outputs for test data
X_test = df_test.drop(['T2LM_L', 'New_feat2', 'New_feat3'], 1) #Feature Matrix
y_test = df_test[['T2LM_L']]

# %%
model.get_params().keys()
# Out:
# dict_keys(['base_estimator', 'learning_rate', 'loss', 'n_estimators', 'random_state'])

# %%
search_space = {'n_estimators': Integer(1, 500),
               'learning_rate': Real(1E-5, 1, prior="uniform"),
               }

bayes_search = BayesSearchCV(model, search_space, cv=3, n_jobs=-1, verbose=1, n_iter=20, random_state=0)

# %%
bayes_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# BayesSearchCV(cv=3, estimator=AdaBoostRegressor(), n_iter=20, n_jobs=-1,
#               random_state=0,
#               search_spaces={'learning_rate': Real(low=1e-05, high=1, prior='uniform', transform='normalize'),
#                              'n_estimators': Integer(low=1, high=500, prior='uniform', transform='normalize')},
#               verbose=1)

# %%
plt.plot(range(1,21), bayes_search.cv_results_['mean_test_score'], '.--')
plt.show()

# %%
bayes_search.best_score_
# Out:
# 0.7287405270126476

# %%
bayes_search.best_params_
# Out:
# OrderedDict([('learning_rate', 0.23252170308998268), ('n_estimators', 122)])

# %%
# Bayes

model = bayes_search.best_estimator_

model.fit(X_train, y_train)

# evaluate the model
pred = model.predict(X_test)

# Print the name and gini importance of each feature
for feature in zip(X_train.columns, model.feature_importances_):
    print(feature)
# Out:
# ('GR', 0.0665460349074098)
# ('PEFZ', 0.04172670548163846)
# ('SP', 0.016899540013670302)
# ('S-sonic', 0.012882447067032711)
# ('SEXP', 0.14903665740498423)
# ('SESP', 0.014174181088319361)
# ('RT', 0.026788676870683086)
# ('RHOB', 0.014163116579752631)
# ('New_feat', 0.09875810720575974)
# ('NPHI', 0.04020097587509085)
# ('PHITCPX', 0.036411246361069946)
# ('K', 0.4223530951777154)
# ('SW', 0.06005921596687341)

# %%
# Evaluate model predictions

model_score_train = model.score(X_train, y_train)
model_score_test = model.score(X_test, y_test)
model_mae = metrics.mean_absolute_error(y_test, pred)
model_mse = metrics.mean_squared_error(y_test, pred)
model_rmse = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('Accuracy of train data:',model_score_train)
print('Accuracy of test data:',model_score_test)
print('Mean Absolute Error:',model_mae)  
print('Mean Squared Error:',model_mse)  
print('Root Mean Squared Error:',model_rmse)
print('MAPE %.3f' % (metrics.mean_absolute_percentage_error(y_test, pred)))
print('MPD %.3f' % (metrics.mean_tweedie_deviance(y_test, pred, power=1)))
# Out:
# Accuracy of train data: 0.777355725566332
# Accuracy of test data: 0.7228542976982167
# Mean Absolute Error: 97.11923003462078
# Mean Squared Error: 15345.425548741838
# Root Mean Squared Error: 123.87665457519361
# MAPE 2.785
# MPD 68.737
