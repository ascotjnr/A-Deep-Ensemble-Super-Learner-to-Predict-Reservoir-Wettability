# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
import sklearn
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_tweedie_deviance
from sklearn.metrics import r2_score

# Hide Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
df_train = pd.read_csv(r"C:\Users\User\Desktop\codes_data\Sandstone\Train_Data_Sand_final.csv")
df_train.head()
# Out:
#           MD     DEN        GR         PERM     NEU     POR  RES_DEP  RES_MED  \
# 0  3153.9180  2.6255  111.6507     0.002856  0.2451  0.0350   2.4820   2.3209
# 1  3059.8872  2.3439   51.3317    13.115390  0.1195  0.1722   6.6866   4.6192
# 2  1271.2000  2.1300   40.2600  5749.670000  0.2800  0.3000   1.3900  27.8000
# 3  3055.9248  2.6137  103.4771     2.204989  0.1980  0.0381   5.8435   5.9513
# 4  3201.4668  2.5744  129.7570     0.005124  0.2313  0.0572   2.2890   2.3533
#
#    RES_SLW  New_feat  New_feat2  New_feat3  New_feat4  New_feat5  New_feat6  \
# 0   2.1170   3.62550     2.8706    1.03500   0.035000  17.121300       1.00
# 1   2.1794   2.61980     2.4634    0.44810   0.047510  10.968882       0.28
# 2  10.4000   2.81212     2.4100    0.98212   0.204636   9.260335       0.68
# 3   4.1498   3.61370     2.8117    1.03810   0.038100  16.445610       1.00
# 4   2.1996   3.57440     2.8057    1.05720   0.057200  18.276937       1.00
#
#    New_feat7       SW        T2LM
# 0   0.646870  1.00000    1.116474
# 1  -2.264150  0.27590  199.653700
# 2  -0.631068  0.68212  146.890100
# 3   0.646870  1.00000   35.907670
# 4   0.646870  1.00000    2.219201

# %%
df_test = pd.read_csv(r"C:\Users\User\Desktop\codes_data\Sandstone\Test_Data_Sand_Final.csv")
df_test.head()
# Out:
#           MD     DEN        GR       PERM     NEU     POR  RES_DEP  RES_MED  \
# 0  1266.3000  2.2700  114.0700   0.050000  0.4100  0.2600   0.4100   0.6100
# 1  3165.9576  2.4988  166.8955   0.016207  0.3344  0.1025   1.9151   1.8651
# 2  3054.4008  2.3077   56.0079  35.652750  0.0987  0.1935  15.1619  12.6920
# 3  3147.0600  2.6167   90.9038   0.000213  0.1945  0.0337   3.2695   3.2479
# 4  3158.9472  2.6398   71.0053   0.000085  0.0599  0.0146  11.9478  11.8025
#
#    RES_SLW  New_feat  New_feat2  New_feat3  New_feat4  New_feat5  New_feat6  \
# 0   0.6500    3.2700     2.6800     1.2600   0.260000  16.091579       1.00
# 1   1.7148    3.4988     2.8332     1.1025   0.102500  20.421520       1.00
# 2   6.6135    2.4718     2.4064     0.3576   0.031753  11.368792       0.16
# 3   2.8147    3.6167     2.8112     1.0337   0.033700  15.422969       1.00
# 4   8.0843    3.6398     2.6997     1.0146   0.014600  13.690865       1.00
#
#    New_feat7      SW        T2LM
# 0   0.646870  1.0000    6.346738
# 1   0.646870  1.0000    2.659890
# 2  -2.713607  0.1641  292.149200
# 3   0.646870  1.0000    3.029543
# 4   0.646870  1.0000    5.726916

# %%
#set MD as index
df_train = df_train.set_index('MD')
df_train.head()
# Out:
#               DEN        GR         PERM     NEU     POR  RES_DEP  RES_MED  \
# MD
# 3153.9180  2.6255  111.6507     0.002856  0.2451  0.0350   2.4820   2.3209
# 3059.8872  2.3439   51.3317    13.115390  0.1195  0.1722   6.6866   4.6192
# 1271.2000  2.1300   40.2600  5749.670000  0.2800  0.3000   1.3900  27.8000
# 3055.9248  2.6137  103.4771     2.204989  0.1980  0.0381   5.8435   5.9513
# 3201.4668  2.5744  129.7570     0.005124  0.2313  0.0572   2.2890   2.3533
#
#            RES_SLW  New_feat  New_feat2  New_feat3  New_feat4  New_feat5  \
# MD
# 3153.9180   2.1170   3.62550     2.8706    1.03500   0.035000  17.121300
# 3059.8872   2.1794   2.61980     2.4634    0.44810   0.047510  10.968882
# 1271.2000  10.4000   2.81212     2.4100    0.98212   0.204636   9.260335
# 3055.9248   4.1498   3.61370     2.8117    1.03810   0.038100  16.445610
# 3201.4668   2.1996   3.57440     2.8057    1.05720   0.057200  18.276937
#
#            New_feat6  New_feat7       SW        T2LM
# MD
# 3153.9180       1.00   0.646870  1.00000    1.116474
# 3059.8872       0.28  -2.264150  0.27590  199.653700
# 1271.2000       0.68  -0.631068  0.68212  146.890100
# 3055.9248       1.00   0.646870  1.00000   35.907670
# 3201.4668       1.00   0.646870  1.00000    2.219201

# %%
# create the inputs and outputs for train data
X_train = df_train.drop(['T2LM', 'New_feat', 'New_feat2', 'New_feat3', 'New_feat4', 'New_feat5', 'New_feat6', 'New_feat7'], 1) #Feature Matrix
y_train = df_train[['T2LM']]

# %%
#set MD as index
df_test = df_test.set_index('MD')
df_test.head()
# Out:
#               DEN        GR       PERM     NEU     POR  RES_DEP  RES_MED  \
# MD
# 1266.3000  2.2700  114.0700   0.050000  0.4100  0.2600   0.4100   0.6100
# 3165.9576  2.4988  166.8955   0.016207  0.3344  0.1025   1.9151   1.8651
# 3054.4008  2.3077   56.0079  35.652750  0.0987  0.1935  15.1619  12.6920
# 3147.0600  2.6167   90.9038   0.000213  0.1945  0.0337   3.2695   3.2479
# 3158.9472  2.6398   71.0053   0.000085  0.0599  0.0146  11.9478  11.8025
#
#            RES_SLW  New_feat  New_feat2  New_feat3  New_feat4  New_feat5  \
# MD
# 1266.3000   0.6500    3.2700     2.6800     1.2600   0.260000  16.091579
# 3165.9576   1.7148    3.4988     2.8332     1.1025   0.102500  20.421520
# 3054.4008   6.6135    2.4718     2.4064     0.3576   0.031753  11.368792
# 3147.0600   2.8147    3.6167     2.8112     1.0337   0.033700  15.422969
# 3158.9472   8.0843    3.6398     2.6997     1.0146   0.014600  13.690865
#
#            New_feat6  New_feat7      SW        T2LM
# MD
# 1266.3000       1.00   0.646870  1.0000    6.346738
# 3165.9576       1.00   0.646870  1.0000    2.659890
# 3054.4008       0.16  -2.713607  0.1641  292.149200
# 3147.0600       1.00   0.646870  1.0000    3.029543
# 3158.9472       1.00   0.646870  1.0000    5.726916

# %%
# create the inputs and outputs for test data
X_test = df_test.drop(['T2LM', 'New_feat', 'New_feat2', 'New_feat3', 'New_feat4', 'New_feat5', 'New_feat6', 'New_feat7'], 1) #Feature Matrix
y_test = df_test[['T2LM']]

# %%
# XGBoost Regressor
model = DecisionTreeRegressor()

model.fit(X_train, y_train)

# evaluate the model
pred = model.predict(X_test)

# Evaluate model predictions

model_score_train = model.score(X_train, y_train)
model_score_test = model.score(X_test, y_test)
model_mae = metrics.mean_absolute_error(y_test, pred)
model_mse = metrics.mean_squared_error(y_test, pred)
model_rmse = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('Accuracy of train data:',model_score_train)
print('Accuracy of test data:',model_score_test)
print('Mean Absolute Error:',model_mae)  
print('Mean Squared Error:',model_mse)  
print('Root Mean Squared Error:',model_rmse)
print('MAPE %.3f' % (metrics.mean_absolute_percentage_error(y_test, pred)))
print('MPD %.3f' % (metrics.mean_tweedie_deviance(y_test, pred, power=1)))
# Out:
# Accuracy of train data: 1.0
# Accuracy of test data: 0.3956998174389623
# Mean Absolute Error: 27.14056232851739
# Mean Squared Error: 6124.929405386754
# Root Mean Squared Error: 78.2619281987529
# MAPE 0.589
# MPD 27.212

# %%
# Print the name and gini importance of each feature
for feature in zip(X_train.columns, model.feature_importances_):
    print(feature)
# Out:
# ('DEN', 0.009721163424430673)
# ('GR', 0.08890212075192999)
# ('PERM', 0.21591052890266307)
# ('NEU', 0.02297612745021785)
# ('POR', 0.01571977909327409)
# ('RES_DEP', 0.03183566885221666)
# ('RES_MED', 0.01406619898943317)
# ('RES_SLW', 0.04051630720566032)
# ('SW', 0.5603521053301742)

# %%
# create the inputs and outputs for train data
X_train = df_train.drop(['T2LM', 'RES_DEP', 'RES_MED', 'RES_SLW', 'DEN', 'POR', 'New_feat4', 'New_feat6'], 1) #Feature Matrix
y_train = df_train[['T2LM']]

# %%
# create the inputs and outputs for test data
X_test = df_test.drop(['T2LM', 'RES_DEP', 'RES_MED', 'RES_SLW', 'DEN', 'POR', 'New_feat4', 'New_feat6'], 1) #Feature Matrix
y_test = df_test[['T2LM']]

# %%
# XGBoost Regressor
model = DecisionTreeRegressor()

model.fit(X_train, y_train)

# evaluate the model
pred = model.predict(X_test)

# Evaluate model predictions

model_score_train = model.score(X_train, y_train)
model_score_test = model.score(X_test, y_test)
model_mae = metrics.mean_absolute_error(y_test, pred)
model_mse = metrics.mean_squared_error(y_test, pred)
model_rmse = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('Accuracy of train data:',model_score_train)
print('Accuracy of test data:',model_score_test)
print('Mean Absolute Error:',model_mae)  
print('Mean Squared Error:',model_mse)  
print('Root Mean Squared Error:',model_rmse)
print('MAPE %.3f' % (metrics.mean_absolute_percentage_error(y_test, pred)))
print('MPD %.3f' % (metrics.mean_tweedie_deviance(y_test, pred, power=1)))
# Out:
# Accuracy of train data: 1.0
# Accuracy of test data: 0.671328030929133
# Mean Absolute Error: 23.36911421270869
# Mean Squared Error: 3331.279165855928
# Root Mean Squared Error: 57.71723456521395
# MAPE 0.589
# MPD 17.201

# %%
# Print the name and gini importance of each feature
for feature in zip(X_train.columns, model.feature_importances_):
    print(feature)
# Out:
# ('GR', 0.0740539902392837)
# ('PERM', 0.1612414486278027)
# ('NEU', 0.030820875836032127)
# ('New_feat', 0.5583823859471818)
# ('New_feat2', 0.03627137732744058)
# ('New_feat3', 0.02090528612852674)
# ('New_feat5', 0.016206749386760838)
# ('New_feat7', 0.07958285943367137)
# ('SW', 0.022535027073300205)

# %% [markdown]
# ## Bayesian optimisation does not run with scikit-learn version 0.24.1. Also, version 0.23.1 does not work calculate MAPE and MPD

# %%
#!pip install scikit-optimize
from skopt import gp_minimize
from skopt import BayesSearchCV
from skopt.space import Integer, Real

# %%
search_space = {'min_samples_leaf': Integer(1, 2000),
               'min_weight_fraction_leaf': Real(1E-20, 0.2, prior="uniform"),
               'max_depth': Integer(1, 2000)}
#cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)

bayes_search = BayesSearchCV(model, search_space, cv=3, n_jobs=-1, verbose=1, n_iter=40, random_state=0)

# %%
bayes_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# BayesSearchCV(cv=3,
#               estimator=DecisionTreeRegressor(max_depth=2000,
#                                               min_samples_leaf=40,
#                                               min_weight_fraction_leaf=1e-20),
#               n_iter=40, n_jobs=-1, random_state=0,
#               search_spaces={'max_depth': Integer(low=1, high=2000, prior='uniform', transform='normalize'),
#                              'min_samples_leaf': Integer(low=1, high=2000, prior='uniform', transform='normalize'),
#                              'min_weight_fraction_leaf': Real(low=1e-20, high=0.2, prior='uniform', transform='normalize')},
#               verbose=1)

# %%
plt.plot(range(1,41), bayes_search.cv_results_['mean_test_score'], '.--')
plt.show()

# %%
bayes_search.best_score_
# Out:
# 0.7100794712766122

# %%
bayes_search.best_params_
# Out:
# OrderedDict([('max_depth', 1194),
#              ('min_samples_leaf', 35),
#              ('min_weight_fraction_leaf', 0.03489640062660728)])

# %%
# Bayes

model = bayes_search.best_estimator_

model.fit(X_train, y_train)

# evaluate the model
pred = model.predict(X_test)

# Print the name and gini importance of each feature
for feature in zip(X_train.columns, model.feature_importances_):
    print(feature)
# Out:
# ('GR', 0.07962105909483719)
# ('PERM', 0.09350672054022263)
# ('NEU', 0.000427965101010271)
# ('New_feat', 0.7310020268488379)
# ('New_feat2', 7.291232742617429e-05)
# ('New_feat3', 0.0)
# ('New_feat5', 0.001820468129926423)
# ('New_feat7', 0.0)
# ('SW', 0.09354884795773956)

# %%
# Evaluate model predictions

model_score_train = model.score(X_train, y_train)
model_score_test = model.score(X_test, y_test)
model_mae = metrics.mean_absolute_error(y_test, pred)
model_mse = metrics.mean_squared_error(y_test, pred)
model_rmse = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('Accuracy of train data:',model_score_train)
print('Accuracy of test data:',model_score_test)
print('Mean Absolute Error:',model_mae)  
print('Mean Squared Error:',model_mse)  
print('Root Mean Squared Error:',model_rmse)
print('MAPE %.3f' % (metrics.mean_absolute_percentage_error(y_test, pred)))
print('MPD %.3f' % (metrics.mean_tweedie_deviance(y_test, pred, power=1)))
# Out:
# Accuracy of train data: 0.7413442347398674
# Accuracy of test data: 0.7053896485904887
# Mean Absolute Error: 22.571856672576352
# Mean Squared Error: 2986.045108959039
# Root Mean Squared Error: 54.64471711848309
# MAPE 0.736
# MPD 18.443

# %%
df_test['Bagging_Test'] = pred
df_test.head()
# Out:
#               DEN        GR       PERM     NEU     POR  RES_DEP  RES_MED  \
# MD
# 1266.3000  2.2700  114.0700   0.050000  0.4100  0.2600   0.4100   0.6100
# 3165.9576  2.4988  166.8955   0.016207  0.3344  0.1025   1.9151   1.8651
# 3054.4008  2.3077   56.0079  35.652750  0.0987  0.1935  15.1619  12.6920
# 3147.0600  2.6167   90.9038   0.000213  0.1945  0.0337   3.2695   3.2479
# 3158.9472  2.6398   71.0053   0.000085  0.0599  0.0146  11.9478  11.8025
#
#            RES_SLW  New_feat  New_feat2  New_feat3  New_feat4  New_feat5  \
# MD
# 1266.3000   0.6500    3.2700     2.6800     1.2600   0.260000  16.091579
# 3165.9576   1.7148    3.4988     2.8332     1.1025   0.102500  20.421520
# 3054.4008   6.6135    2.4718     2.4064     0.3576   0.031753  11.368792
# 3147.0600   2.8147    3.6167     2.8112     1.0337   0.033700  15.422969
# 3158.9472   8.0843    3.6398     2.6997     1.0146   0.014600  13.690865
#
#            New_feat6  New_feat7      SW        T2LM  Bagging_Test
# MD
# 1266.3000       1.00   0.646870  1.0000    6.346738      6.161010
# 3165.9576       1.00   0.646870  1.0000    2.659890      1.972535
# 3054.4008       0.16  -2.713607  0.1641  292.149200    185.311300
# 3147.0600       1.00   0.646870  1.0000    3.029543      2.388052
# 3158.9472       1.00   0.646870  1.0000    5.726916      5.526569

# %%
df_test.to_csv('Predicted_Test_Data_DT.csv')
